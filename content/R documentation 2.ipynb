# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Phase stabilities with path-dependence
#
# Version: March 2023. Contact: mjmayne@outlook.com
#
# ![image.png](attachment:image.png)
# <img src = (attachment:image.png) width="600" height="300">
# [TOC]
